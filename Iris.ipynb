# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('IRIS.csv')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.plot(x= 'sepal_width')
# Out:
# <Axes: xlabel='sepal_width'>

# %%
data.plot(subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
data.plot.scatter(x ='sepal_width', y ='sepal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
data.plot.scatter(x ='sepal_width', y ='sepal_length', figsize=(10,6), c ='r')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
ax=data.plot.scatter(x="sepal_width", y="sepal_length", color="r")
data.plot.scatter(x="sepal_width", y="petal_length", color="g", ax=ax)
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_length'>

# %%
dataset = data.sample(frac = 0.1)

# %%
dataset['petal_length'].plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: >

# %%
dataset.plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: >

# %%
dataset.plot(kind='bar', figsize=(10, 6), stacked=True)
# Out:
# <Axes: >

# %%
data.plot.area()
# Out:
# <Axes: >

# %%
dataset.plot(kind='bar', figsize=(10, 6), stacked=True)
# Out:
# <Axes: >

# %%
data.plot.area(y= 'petal_width',stacked=False)
# Out:
# <Axes: >

# %%
data['petal_width'].plot.box()
# Out:
# <Axes: >

# %%
data.plot.box()
# Out:
# <Axes: >

# %%
data.boxplot(by='species', figsize=(10, 6))
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)

# %%
data.boxplot(column=['petal_width'], by='species', figsize=(8, 6), grid=False)
# Out:
# <Axes: title={'center': 'petal_width'}, xlabel='species'>

# %%
dataset = data.sample(frac = 0.1)

# %%
dataset['sepal_length'].plot.pie()
# Out:
# <Axes: ylabel='sepal_length'>

# %%
Data = pd.DataFrame(np.random.rand(6, 3),
columns=('First', 'Second', 'Third'))

# %%
Data.plot.pie(subplots=True, figsize=(10, 6))
# Out:
# array([<Axes: ylabel='First'>, <Axes: ylabel='Second'>,
#        <Axes: ylabel='Third'>], dtype=object)

# %%
data['petal_length'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
data.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
data.plot.hexbin('petal_length', 'petal_width', gridsize=9)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>
